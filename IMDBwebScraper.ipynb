# %%
import requests
from bs4 import BeautifulSoup

# %%
column=['Title','Year','Summary','Rating','Genre','Actors','Directors','Writers']

# %%
import pandas as pd 

movie_db = pd.DataFrame()

mainlist=[]

# %%
urls = ['https://www.imdb.com/title/tt2245084/?ref_=fn_al_tt_1',#Baymax
       'https://www.imdb.com/title/tt0351283/?ref_=tt_sims_tt_i_4',#Madagascar
       'https://www.imdb.com/title/tt9683478/',#the half of it
        'https://www.imdb.com/title/tt6710474/?pf_rd_m=A2FGELUUNOQJNL&pf_rd_p=ea4e08e1-c8a3-47b5-ac3a-75026647c16e&pf_rd_r=GT07B094NDJXQRYRVFN8&pf_rd_s=center-1&pf_rd_t=15506&pf_rd_i=moviemeter&ref_=chtmvm_tt_7'#everything everywhere all at once
        ,'https://www.imdb.com/title/tt0126029/?ref_=ls_mv_close',#Shrek
        'https://www.imdb.com/title/tt2953050/?ref_=adv_li_tt',#Encanto
        'https://www.imdb.com/title/tt8097030/?ref_=tt_sims_tt_i_1',#Turning Red
        'https://www.imdb.com/title/tt2948372/?ref_=tt_sims_tt_i_6',#Soul
        'https://www.imdb.com/title/tt2380307/?ref_=tt_sims_tt_i_1',#Coco
        'https://www.imdb.com/title/tt0910970/?ref_=tt_sims_tt_i_3'#wall-e
        'https://www.imdb.com/title/tt0198781/?ref_=tt_sims_tt_i_3',#Monsters Inc.
        'https://www.imdb.com/title/tt0382932/?ref_=tt_sims_tt_i_4' , #Ratatouille
        'https://www.imdb.com/title/tt2883512/?ref_=tt_sims_tt_i_1',#Chef
        'https://www.imdb.com/title/tt0114709/?ref_=tt_sims_tt_i_7',#toyStory
        'https://www.imdb.com/title/tt0266543/?ref_=tt_sims_tt_i_5',#FindingNemo
        'https://www.imdb.com/title/tt2277860/?ref_=tt_sims_tt_i_6',#finding dory
        'https://www.imdb.com/title/tt1772341/?ref_=tt_sims_tt_i_4',#Wreck-itRalph
        'https://www.imdb.com/title/tt2948356/?ref_=tt_sims_tt_i_4',#Zootopia
        'https://www.imdb.com/title/tt2948356/?ref_=tt_sims_tt_i_4',#Moana
        'https://www.imdb.com/title/tt0398286/?ref_=tt_sims_tt_i_3',#tangled
        'https://www.imdb.com/title/tt1217209/?ref_=tt_sims_tt_i_2',#Brave
        'https://www.imdb.com/title/tt0317219/?ref_=tt_sims_tt_i_10',#cars
        #add more movies here
       ]

for url in urls: 
    ls=[]
    response=requests.get(url)
    soup = BeautifulSoup(response.content ,"html.parser" )
    title= (soup.title).string
    ls.append(title)
    year= soup.find(class_="ipc-link ipc-link--baseAlt ipc-link--inherit-color sc-8c396aa2-1 WIUyh").string
    ls.append(year)
    summary=soup.find(class_="sc-16ede01-2 gXUyNh").string
    ls.append(summary)
    rating = soup.find(class_="sc-7ab21ed2-1 jGRxWM").string
    ls.append(rating)
    genre = soup.find_all(class_="ipc-inline-list__item ipc-chip__text")
    genrelist=[]
    for i in genre:
        genrelist.append(i.string)
    ls.append(genrelist)
    top_actors=soup.find_all(class_="sc-18baf029-1 gJhRzH")
    topActorList=[]
    for i in top_actors:
        topActorList.append(i.string)

    characterAs = soup.find_all(class_="sc-18baf029-4 iYNZoy")
    topCharacterList=[]
    for i in characterAs:
        topCharacterList.append(i.string)
    for i in range( len(topCharacterList)):
        topActorList[i] = topActorList[i] +' ' +topCharacterList[i]
    ls.append(topActorList)
    director=soup.find_all('a' , attrs={'class':'ipc-metadata-list-item__list-content-item ipc-metadata-list-item__list-content-item--link'})
    directors=[]
    directors.append(director[0].string)
    directors.append(director[1].string)
    ls.append(directors)
    writers=[]
    for i in range(3):
        writers.append(director[2+i].string)
    ls.append(writers)
    mainlist.append(ls)
print(mainlist)
# Out:
# [['Baymax (2014) - IMDb', '2014', 'A special bond develops between plus-sized inflatable robot Baymax and prodigy Hiro Hamada, who together team up with a group of friends to form a band of high-tech heroes.', '7.8', ['Animation', 'Action', 'Adventure'], ['Ryan Potter as Hiro', 'Scott Adsit as Baymax', 'Jamie Chung as Go Go', 'T.J. Miller as Fred', 'Daniel Henney as Tadashi', 'Damon Wayans Jr. as Wasabi', 'Genesis Rodriguez as Honey Lemon', 'James Cromwell as Robert Callaghan', 'Alan Tudyk as Alistair Krei', 'Maya Rudolph as Cass', 'Abraham Benrubi as General', 'Katie Lowes as Abigail', 'Billy Bush as Newscaster', 'Daniel Gerson as Desk Sergeant', 'Paul Briggs as Yama', 'Charlotte Gulezian as Ringleader', 'David Shaughnessy as Heathcliff', 'Kirk Baily as Additional Voice'], ['Don Hall', 'Chris Williams'], ['Jordan Roberts', 'Robert L. Baird', 'Daniel Gerson']], ['Madagascar (2005) - IMDb', '2005', 'A group of animals who have spent all their life in a New York zoo end up in the jungles of Madagascar, and must adjust to living in the wild.', '6.9', ['Animation', 'Adventure', 'Comedy'], ['Chris Rock as Marty', 'Ben Stiller as Alex', 'David Schwimmer as Melman', 'Jada Pinkett Smith as Gloria', 'Sacha Baron Cohen as Julien', 'Cedric the Entertainer as Maurice', 'Andy Richter as Mort', 'Tom McGrath as Skipper', 'Christopher Knights as Private', 'Chris Miller as Kowalski', 'Conrad Vernon as Mason', 'Eric Darnell as Zoo Announcer', 'David Cowgill as Police Horse', 'Steve Apostolina as Police Officer', 'Elisa Gabrielli as Old Lady', 'Devika Parikh as News Reporter', 'David P. Smith as Spider', 'Cody Cameron as Willie'], ['Eric Darnell', 'Tom McGrath'], ['Mark Burton', 'Billy Frolick', 'Eric Darnell']], ['The Half of It (2020) - IMDb', '2020', "When smart but cash-strapped teen Ellie Chu agrees to write a love letter for a jock, she doesn't expect to become his friend - or fall for his crush.", '6.9', ['Comedy', 'Drama', 'Romance'], ['Leah Lewis as Ellie Chu', 'Daniel Diemer as Paul Munsky', 'Alexxis Lemire as Aster Flores', 'Wolfgang Novogratz as Trig Carson', 'Collin Chou as Edwin Chu', 'Becky Ann Baker as Mrs. Geselschap', 'Enrique Murciano as Deacon Flores', 'MacIntyre Dixon as Father Shanley', 'Catherine Curtin as Colleen Munsky', 'Alec Tincher as Senior Guy (In Hallway)', 'Bonnie Flannery as Senior Girl (In Hallway)', 'Tyler Crozier as Truck Teen', 'Spencer Wawak as Hangout Dude', 'Patrick T. Johnson as Tom Carson', 'Gabi Samels as Quaddie Girl #1 (Amber)', 'Haley Murphy as Quaddie Girl #2 (Solange)', 'Patrick Noonan as Squahamish Football Coach', 'Dean Tierney as Greg Munsky'], ['Alice Wu', 'Alice Wu'], ['Leah Lewis', 'Daniel Diemer', 'Alexxis Lemire']], ['Everything Everywhere All at Once (2022) - IMDb', '2022', 'An aging Chinese immigrant is swept up in an insane adventure, where she alone can save the world by exploring other universes connecting with the lives she could have led.', '8.3', ['Action', 'Adventure', 'Comedy'], ['Michelle Yeoh as Evelyn Wang', 'Stephanie Hsu as Joy Wang', 'Ke Huy Quan as Waymond Wang', 'James Hong as Gong Gong', 'Jamie Lee Curtis as Deirdre Beaubeirdre', 'Tallie Medel as Becky Sregor', 'Jenny Slate as Dog Mom', 'Harry Shum Jr. as Chad', 'Biff Wiff as Rick', 'Sunita Mani as TV Musical - Queen', 'Aaron Lazar as TV Musical - Soldier', 'Brian Le as Alpha Jumper - Trophy', 'Andy Le as Alpha Jumper - Bigger Trophy', 'Narayana Cabral as Security Guard', 'Chelsey Goldsmith as Security Guard', 'Craig Henningsen as Security Guard', 'Anthony Molinari as Police - Confetti', 'Dan Brown as Police - Salsa'], ['Dan Kwan', 'Daniel Scheinert'], ['Dan Kwan', 'Daniel Scheinert', 'Michelle Yeoh']], ['Shrek (2001) - IMDb', '2001', 'A mean lord exiles fairytale creatures to the swamp of a grumpy ogre, who must go on a quest and rescue a princess for the lord in order to get his land back.', '7.9', ['Animation', 'Adventure', 'Comedy'], ['Mike Myers as Shrek', 'Eddie Murphy as Donkey', 'Cameron Diaz as Princess Fiona', ' ...

# %%
movie_db=pd.DataFrame(mainlist,columns=column)

# %%
movie_db=movie_db.sort_values(by='Rating', ascending=False)

# %%
movie_db.reset_index(level=None, drop=True, inplace=False, col_level=0, col_fill="")
# Out:
#                                               Title  Year  \
# 0                                Coco (2017) - IMDb  2017
# 1                              WALL·E (2008) - IMDb  2008
# 2                           Toy Story (1995) - IMDb  1995
# 3   Everything Everywhere All at Once (2022) - IMDb  2022
# 4                        Finding Nemo (2003) - IMDb  2003
# 5                         Ratatouille (2007) - IMDb  2007
# 6                            Zootopia (2016) - IMDb  2016
# 7                            Zootopia (2016) - IMDb  2016
# 8                                Soul (2020) - IMDb  2020
# 9                               Shrek (2001) - IMDb  2001
# 10                             Baymax (2014) - IMDb  2014
# 11                     Wreck-It Ralph (2012) - IMDb  2012
# 12                            Tangled (2010) - IMDb  2010
# 13                               Chef (2014) - IMDb  2014
# 14                       Finding Dory (2016) - IMDb  2016
# 15                            Encanto (2021) - IMDb  2021
# 16                               Cars (2006) - IMDb  2006
# 17                              Brave (2012) - IMDb  2012
# 18                        Turning Red (2022) - IMDb  2022
# 19                         Madagascar (2005) - IMDb  2005
# 20                     The Half of It (2020) - IMDb  2020
#
#                                               Summary Rating  \
# 0   Aspiring musician Miguel, confronted with his ...    8.4
# 1   In the distant future, a small waste-collectin...    8.4
# 2   A cowboy doll is profoundly threatened and jea...    8.3
# 3   An aging Chinese immigrant is swept up in an i...    8.3
# 4   After his son is captured in the Great Barrier...    8.2
# 5   A rat who can cook makes an unusual alliance w...    8.1
# 6   In a city of anthropomorphic animals, a rookie...    8.0
# 7   In a city of anthropomorphic animals, a rookie...    8.0
# 8   After landing the gig of a lifetime, a New Yor...    8.0
# 9   A mean lord exiles fairytale creatures to the ...    7.9
# 10  A special bond develops between plus-sized inf...    7.8
# 11  A video game villain wants to be a hero and se...    7.7
# 12  The magically long-haired Rapunzel has spent h...    7.7
# 13  A head chef quits his restaurant job and buys ...    7.3
# 14  Friendly but forgetful blue tang Dory begins a...    7.3
# 15  A Colombian teenage girl has to face the frust...    7.2
# 16  A hot-shot race-car named Lightning McQueen ge...    7.2
# 17  Determined to make her own path in life, Princ...    7.1
# 18  A 13-year-old girl named Meilin turns into a g...    7.0
# 19  A group of animals who have spent all their li...    6.9
# 20  When smart but cash-strapped teen Ellie Chu ag...    6.9
#
#                              Genre  \
# 0   [Animation, Adventure, Comedy]
# 1   [Animation, Adventure, Family]
# 2   [Animation, Adventure, Comedy]
# 3      [Action, Adventure, Comedy]
# 4   [Animation, Adventure, Comedy]
# 5   [Animation, Adventure, Comedy]
# 6   [Animation, Adventure, Comedy]
# 7   [Animation, Adventure, Comedy]
# 8   [Animation, Adventure, Comedy]
# 9   [Animation, Adventure, Comedy]
# 10  [Animation, Action, Adventure]
# 11  [Animation, Adventure, Comedy]
# 12  [Animation, Adventure, Comedy]
# 13      [Adventure, Comedy, Drama]
# 14  [Animation, Adventure, Comedy]
# 15     [Animation, Comedy, Family]
# 16  [Animation, Adventure, Comedy]
# 17  [Animation, Adventure, Comedy]
# 18  [Animation, Adventure, Comedy]
# 19  [Animation, Adventure, Comedy]
# 20        [Comedy, Drama, Romance]
#
#                                                Actors  \
# 0   [Anthony Gonzalez as Miguel, Gael García Berna...
# 1   [Ben Burtt as WALL·E, Elissa Knight as EVE, Je...
# 2   [Tom Hanks as Woody, Tim Allen as Buzz Lightye...
# 3   [Michelle Yeoh as Evelyn Wang, Stephanie Hsu a...
# 4   [Albert Brooks as Marlin, Ellen DeGeneres as D...
# 5   [Brad Garrett as Gusteau, Lou Romano as Lingui...
# 6   [Ginnifer Goodwin as Judy Hopps, Jason Bateman...
# 7   [Ginnifer Goodwin as Judy Hopps, Jason Bateman...
# 8   [Jamie Foxx as Joe, Tina Fey as 22, Graham Nor...
# 9   [Mike Myers as Shrek, Eddie Murphy as Donkey, ...
# 10  [Ryan Potter as Hiro, Scott Adsit as Baymax, J...
# 11  [John C. Reilly as Ralph, Jack McBrayer as Fel...
# 12  [Mandy Moore as Rapunzel, Zachary Levi as Flyn...
# 13  [Jon Favreau as Carl Casper, Robert Downey Jr....
# 14  [Ellen DeGeneres as Dory, Albert Brooks as Mar...
# 15  [Stephanie Beatriz as Mirabel, María Cecilia B...
# 16  [Owen Wilson as Lightning McQueen, Bonnie Hunt...
# 17  [Kelly Macdonald as Merida, Billy Connolly as ...
# 18  [Rosalie Chiang as Meilin, Sandra Oh as Ming, ...
# 19  [Chris Rock as Marty, Ben Stiller as Alex, Dav...
# 20  [Leah Lewis as Ellie Chu, Daniel Diemer as Pau...
#
#                            Directors  \
# 0       [Lee Unkrich, Adrian Molina]
# 1   [Andrew Stanton, Andrew Stanton]
# 2     [John Lasseter, John Lasseter]
# 3       [Dan Kwan, Daniel Scheinert]
# 4      [Andrew Stanton, Lee Unkrich]
# 5           [Brad Bird, Jan Pinkava]
# 6         [Byron Howard, Rich Moore]
# 7         [Byron Howard, Rich Moore]
# 8         [Pete Docter, Kemp Powers]
# 9     [Andrew Adamson, Vicky Jenson]
# 10        [Don Hall, Chris Williams]
# 11          [Rich Moore, Rich Moore]
# 12      [Nathan Greno, Byron Howard]
# 13        [Jon Favreau, Jon Favreau]
# 14   [Andrew Stanton, Angus MacLane]
# 15        [Jared Bush, Byron Howard]
# 16        [John Lasseter, Joe Ranft]
# 17    [Mark Andrews, Brenda Chapman]
# 18            [Domee Shi, Domee Shi]
# 19       [Eric Darnell, Tom McGrath]
# 20              [Alice Wu, Alice Wu]
#
#                                               Writers
# 0          [Lee Unkrich, Jason Katz, Matthew Aldrich]
# 1               [Pete Docter, Jim Reardon, Ben Burtt]
# 2            [Pete Docter, Andrew Stanton, Tom Hanks]
# 3         [Dan Kwan, Daniel Scheinert, Michelle Yeoh]
# 4      [Andrew Stanton, Bob Peterson, David Reynolds]
# 5            [Brad Bird, Jan Pinkava, Jim Capobianco]
# 6              [Jared Bush, Byron Howard, Rich Moore]
# 7              [Jared Bush, Byron Howard, Rich Moore]
# 8              [Pete Docter, Mike Jones, Kemp Powers]
# 9          [William Steig, Ted Elliott, Terry Rossio]
# 10   [Jordan Roberts, Robert L. Baird, Daniel Gerson]
# 11       [Phil Johnston, Jim Reardon, John C. Reilly]
# 12         [Dan Fogelman, Jacob Grimm, Wilhelm Grimm]
# 13  [Jon Favreau, Robert Downey Jr., Scarlett Joha...
# 14  [Andrew Stanton, Victoria Strouse, Ellen DeGen...
# 15  [Charise Castro Smith, Charise Castro Smith, J...
# 16         [John Lasseter, Joe Ranft, Jorgen Klubien]
# 17      [Steve Purcell, Brenda Chapman, Mark Andrews]
# 18       [Julia Cho, Sarah Streicher, Rosalie Chiang]
# 19         [Mark Burton, Billy Frolick, Eric Darnell]
# 20        [Leah Lewis, Daniel Diemer, Alexxis Lemire]

# %%
import sys
# !{sys.executable} -m pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in c:\users\guru\anaconda\lib\site-packages (3.0.7)
# Requirement already satisfied: et-xmlfile in c:\users\guru\anaconda\lib\site-packages (from openpyxl) (1.0.1)

# %%
# edit the name u want the data to be saved in. I have used ImdbDataset.xlsx
writer = pd.ExcelWriter('ImdbDataset.xlsx')
movie_db.to_excel(writer)
writer.save()
